# %% [markdown]
# # 03 · U-Net Transfer & DiT
#
# This notebook will be fleshed out once HRPlanes arrives. For now it simply checks the dummy UNet decoder.

# %%
# %run ../src/train_unet_aux.py --epochs 1
