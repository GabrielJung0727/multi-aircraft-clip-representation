# %% [markdown]
# # 02 · CLIP Training (Multi-Dataset)
#
# Start with PlanesNet so the pipeline is ready when HRPlanes / FGVC downloads finish.

# %%
# %run ../src/train_clip.py --epochs 1 --split train
