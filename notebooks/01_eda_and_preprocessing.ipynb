# %% [markdown]
# # 01 · EDA & Preprocessing
#
# Initial exploration notebook focused on PlanesNet while the remaining datasets download.

# %%
from pathlib import Path
from datasets.planesnet_dataset import PlanesNetDataset

dataset = PlanesNetDataset(root=Path('data/planesnet'))
len(dataset)
